# %% [markdown]
# # <center>Machine Learning Project</center>
#
# ** **
# ## <center>*02 - Preprocessing*</center>
#
# ** **
#
# The members of the `team` are:
# - Ana Farinha - 20211514
# - Francisco Capontes - 20211692
# - Sofia Gomes - 20240848
# - Rui Lourenço - 2021639

# %% [markdown]
# ## <span style="color:#568789"> Notebook  </span>
#
# After exploring our data and removing the duplicates in the other notebook, in this one we are going to search for incoherencies, handle the missing values that can be imputed with simple techniques that do not tend to leak data, remove outliers, create some new features, transform existing features, explore the results of our preprocessing and encode our variables.

# %% [markdown]
# ## <span style="color:#568789"> Table of Contents </span>
#
# <a class="anchor" id="top"></a>
#
# 1. [Import Libraries](#one-bullet) <br>
#
# 2. [Import Datasets](#two-bullet) <br>
#
# 3. [Data Types](#three-bullet) <br>
#
# 4. [Incoherencies](#four-bullet) <br>
#
# 5. [Handling Missing Values](#five-bullet) <br>
#
# 6. [Removing Outliers  & Changing Distributions](#six-bullet) <br>
#
# 7. [Feature Engineering](#seven-bullet) <br>
#     7.1 [Creating New Features](#seven-one-bullet) <br>
#     7.2 [Transforming Existing Features](#seven-two-bullet) <br>
#
# 8. [Visualizations](#eight-bullet) <br>
#
# 9. [Variable Encoding](#nine-bullet) <br>
#
# 10. [Export Datasets](#ten-bullet) <br>

# %% [markdown]
# <a class="anchor" id="one-bullet"></a>
#
# ## <span style="color:#568789"> 1. Import Libraries</span>

# %% [markdown]
# The first step is to import the necessary libraries.

# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
import pandas as pd

# Missing Values
import missingno as msno

# Visualization libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Encoding
from sklearn.preprocessing import LabelEncoder

# Others
from utils.utils import *

# %% [markdown]
# <a class="anchor" id="two-bullet">
#
# ## <span style="color:#568789"> 2. Import Datasets</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# Next, we start by importing the training dataset.

# %%
train_df = pd.read_csv('../data/eda_data/train_data.csv', index_col='Claim Identifier')
train_df
# Out:
# C:\Users\ruipb\AppData\Local\Temp\ipykernel_37292\1161257887.py:1: DtypeWarning: Columns (29) have mixed types. Specify dtype option on import or set low_memory=False.
#   train_df = pd.read_csv('../data/eda_data/train_data.csv', index_col='Claim Identifier')
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393875             2019-12-30             31                              N
# 5393091             2019-08-30             46                              N
# 5393889             2019-12-06             40                              N
# 5393887             2019-12-30             61                              N
# 5393863             2019-12-26             67                              N
# ...                        ...            ...                            ...
# 6165265             2022-12-14             35                              N
# 6165285             2022-12-15             33                              N
# 6165506             2022-12-13             61                              N
# 6165339             2022-12-14             24                              N
# 6165075             2022-12-13             72                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393875             2020-01-01                       N                 0.00
# 5393091             2020-01-01                       Y              1745.93
# 5393889             2020-01-01                       N              1434.80
# 5393887             2020-01-01                       N                  NaN
# 5393863             2020-01-01                       N                 0.00
# ...                        ...                     ...                  ...
# 6165265             2022-12-30                       N                 0.00
# 6165285             2022-12-31                       N                 0.00
# 6165506             2022-12-31                       N               991.08
# 6165339             2022-12-31                       N                 0.00
# 6165075             2022-12-31                       N                 0.00
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 5393875               1988.0  2019-12-31         NaN
# 5393091               1973.0  2020-01-01  2020-01-14
# 5393889               1979.0  2020-01-01         NaN
# 5393887               1958.0  2019-12-31         NaN
# 5393863               1952.0  2019-12-31         NaN
# ...                      ...         ...         ...
# 6165265               1987.0  2022-12-30         NaN
# 6165285               1989.0  2022-12-31         NaN
# 6165506               1961.0  2022-12-31         NaN
# 6165339               1998.0  2022-12-31         NaN
# 6165075               1950.0  2022-12-31         NaN
#
#                                     Carrier Name  ...  \
# Claim Identifier                                  ...
# 5393875               NEW HAMPSHIRE INSURANCE CO  ...
# 5393091             ZURICH AMERICAN INSURANCE CO  ...
# 5393889                INDEMNITY INSURANCE CO OF  ...
# 5393887                     STATE INSURANCE FUND  ...
# 5393863              INDEMNITY INS. OF N AMERICA  ...
# ...                                          ...  ...
# 6165265                     STATE INSURANCE FUND  ...
# 6165285                       WESCO INSURANCE CO  ...
# 6165506           SECURITY NATIONAL INSURANCE CO  ...
# 6165339            TECHNOLOGY INSURANCE CO. INC.  ...
# 6165075            TECHNOLOGY INSURANCE CO. INC.  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                               27.0
# 5393091                               97.0
# 5393889                               79.0
# 5393887                               16.0
# 5393863                               31.0
# ...                                    ...
# 6165265                               45.0
# 6165285                               74.0
# 6165506                               98.0
# 6165339                               59.0
# 6165075                               25.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393875                          FROM LIQUID OR GREASE SPILLS
# 5393091                                     REPETITIVE MOTION
# 5393889                        OBJECT BEING LIFTED OR HANDLED
# 5393887                       HAND TOOL, UTENSIL; NOT POWERED
# 5393863                               FALL, SLIP OR TRIP, NOC
# ...                                                       ...
# 6165265           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# 6165285                FELLOW WORKER, PATIENT OR OTHER PERSON
# 6165506                                       CUMULATIVE, NOC
# 6165339                               USING TOOL OR MACHINERY
# 6165075                      FROM DIFFERENT LEVEL (ELEVATION)
#
#                  WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# Claim Identifier
# 5393875                                10.0                         CONTUSION
# 5393091                                49.0                    SPRAIN OR TEAR
# 5393889                                 7.0                        CONCUSSION
# 5393887                                43.0                          PUNCTURE
# 5393863                                10.0                         CONTUSION
# ...                                     ...                               ...
# 6165265                                10.0                         CONTUSION
# 6165285                                37.0                      INFLAMMATION
# 6165506                                80.0  ALL OTHER CUMULATIVE INJURY, NOC
# 6165339                                59.0  ALL OTHER SPECIFIC INJURIES, NOC
# 6165075                                90.0   MULTIPLE PHYSICAL INJURIES ONLY
#
#                  WCIO Part Of Body Code WCIO Part Of Body Description  \
# Claim Identifier
# 5393875                            62.0                      BUTTOCKS
# 5393091                            38.0                   SHOULDER(S)
# 5393889                            10.0          MULTIPLE HEAD INJURY
# 5393887                            36.0                     FINGER(S)
# 5393863                            38.0                   SHOULDER(S)
# ...                                 ...                           ...
# 6165265                            42.0               LOWER BACK AREA
# 6165285                            35.0                          HAND
# 6165506                            34.0                         WRIST
# 6165339                            55.0                         ANKLE
# 6165075                            -9.0                      MULTIPLE
#
#                  Zip Code  Agreement Reached      WCB Decision  \
# Claim Identifier
# 5393875             13662                0.0  Not Work Related
# 5393091             14569                1.0  Not Work Related
# 5393889             12589                0.0  Not Work Related
# 5393887             12603                0.0  Not Work Related
# 5393863             11772                0.0  Not Work Related
# ...                   ...                ...               ...
# 6165265           10467.0                0.0  Not Work Related
# 6165285           11590.0                0.0  Not Work Related
# 6165506           14227.0                0.0  Not Work Related
# 6165339           10029.0                0.0  Not Work Related
# 6165075           12779.0                0.0  Not Work Related
#
#                  Number of Dependents
# Claim Identifier
# 5393875                           1.0
# 5393091                           4.0
# 5393889                           6.0
# 5393887                           1.0
# 5393863                           5.0
# ...                               ...
# 6165265                           4.0
# 6165285                           6.0
# 6165506                           3.0
# 6165339                           5.0
# 6165075                           3.0
#
# [574024 rows x 32 columns]

# %%
# Save number of rows
initial_row_count = train_df.shape[0]

# %% [markdown]
# Following, we import the test dataset so that the simple transformations an imputations can be done in both datasets, while avoiding data leakage.

# %%
test_df = pd.read_csv('../data/eda_data/test_data.csv', index_col='Claim Identifier')
test_df
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 6165911             2022-12-24             19                              N
# 6166141             2022-11-20             19                              N
# 6165907             2022-12-26             59                              N
# 6166047             2022-12-28             55                              N
# 6166102             2022-12-20             25                              N
# ...                        ...            ...                            ...
# 6553137             2012-09-12             52                              N
# 6553119             2024-05-22             59                              N
# 6553542             2024-05-06             45                              N
# 6553455             2024-02-24             42                              N
# 6553594                    NaN              0                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 6165911             2023-01-02                       N                  NaN
# 6166141             2023-01-02                       N                  NaN
# 6165907             2023-01-02                       N                  0.0
# 6166047             2023-01-02                       N                  0.0
# 6166102             2023-01-02                       N                  0.0
# ...                        ...                     ...                  ...
# 6553137             2024-06-05                       N                  NaN
# 6553119             2024-06-05                       Y                  0.0
# 6553542             2024-06-05                       Y                  0.0
# 6553455             2024-06-05                       Y                  0.0
# 6553594             2024-06-05                       Y                  0.0
#
#                   Birth Year    C-2 Date    C-3 Date  \
# Claim Identifier
# 6165911               2003.0  2023-01-02         NaN
# 6166141               2003.0  2023-01-02         NaN
# 6165907               1963.0  2022-12-31         NaN
# 6166047                  0.0  2023-01-02         NaN
# 6166102               1997.0  2022-12-31         NaN
# ...                      ...         ...         ...
# 6553137               1960.0  2012-10-23         NaN
# 6553119               1965.0         NaN  2024-05-28
# 6553542               1979.0         NaN         NaN
# 6553455               1981.0         NaN  2024-05-21
# 6553594                  NaN         NaN  2024-05-28
#
#                                    Carrier Name  ... Medical Fee Region  \
# Claim Identifier                                 ...
# 6165911               INDEMNITY INSURANCE CO OF  ...                 IV
# 6166141                 A I U INSURANCE COMPANY  ...                 IV
# 6165907               AMGUARD INSURANCE COMPANY  ...                III
# 6166047             INDEMNITY INS. OF N AMERICA  ...                 IV
# 6166102              NEW HAMPSHIRE INSURANCE CO  ...                 IV
# ...                                         ...  ...                ...
# 6553137                    STATE INSURANCE FUND  ...                  I
# 6553119                   NYC TRANSIT AUTHORITY  ...                 IV
# 6553542                    STATE INSURANCE FUND  ...                 IV
# 6553455           NEW YORK BLACK CAR OPERATORS'  ...                 IV
# 6553594            CNY OTHER THAN ED, HED WATER  ...                 IV
#
#                  OIICS Nature of Injury Description WCIO Cause of Injury Code  \
# Claim Identifier
# 6165911                                         NaN                      31.0
# 6166141                                         NaN                      75.0
# 6165907                                         NaN                      68.0
# 6166047                                         NaN                      25.0
# 6166102                                         NaN                      79.0
# ...                                             ...                       ...
# 6553137                                         NaN                       NaN
# 6553119                                         NaN                       NaN
# 6553542                                         NaN                       NaN
# 6553455                                         NaN                       NaN
# 6553594                                         NaN                       NaN
#
#                   WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 6165911                    FALL, SLIP OR TRIP, NOC                       10.0
# 6166141                   FALLING OR FLYING OBJECT                       10.0
# 6165907                          STATIONARY OBJECT                       49.0
# 6166047           FROM DIFFERENT LEVEL (ELEVATION)                       10.0
# 6166102             OBJECT BEING LIFTED OR HANDLED                       40.0
# ...                                            ...                        ...
# 6553137                                        NaN                        NaN
# 6553119                                        NaN                        NaN
# 6553542                                        NaN                        NaN
# 6553455                                        NaN                        NaN
# 6553594                                        NaN                        NaN
#
#                  WCIO Nature of Injury Description  WCIO Part Of Body Code  \
# Claim Identifier
# 6165911                                  CONTUSION                    54.0
# 6166141                                  CONTUSION                    10.0
# 6165907                             SPRAIN OR TEAR                    62.0
# 6166047                                  CONTUSION                    53.0
# 6166102                                 LACERATION                    37.0
# ...                                            ...                     ...
# 6553137                                        NaN                     NaN
# 6553119                                        NaN                     NaN
# 6553542                                        NaN                     NaN
# 6553455                                        NaN                     NaN
# 6553594                                        NaN                     NaN
#
#                   WCIO Part Of Body Description Zip Code Number of Dependents
# Claim Identifier
# 6165911                               LOWER LEG    10466                    1
# 6166141                    MULTIPLE HEAD INJURY    11691                    1
# 6165907                                BUTTOCKS    10604                    0
# 6166047                                    KNEE    11411                    6
# 6166102                                   THUMB    11212                    5
# ...                                         ...      ...                  ...
# 6553137                                     NaN    13619                    5
# 6553119                                     NaN    11776                    1
# 6553542                                     NaN    11368                    5
# 6553455                                     NaN    11432                    5
# 6553594                                     NaN    10302                    5
#
# [387975 rows x 29 columns]

# %% [markdown]
# <a class="anchor" id="three-bullet">
#
# ## <span style="color:#568789"> 3. Data Types</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# As all necessary analysis and explanations were given in the previous notebook, this notebook will only have the necessary changes on the data types.

# %%
datatype_changes([train_df, test_df])

# %% [markdown]
# <a class="anchor" id="four-bullet">
#
# ## <span style="color:#568789"> 4. Incoherencies</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# 1. `Age at Injury` with non-valid values
#
# According to NY laws, the minimum age to work is 14 years old with some restrictions. Any restrictions are lifted after 18 years old. Additionally, we also defined an upper limit of 119 because the oldest person alive between 2020 and 2022 was 119 years old. The values not within limits where replaced by missing values.

# %%
limit_feature([train_df, test_df], 'Age at Injury', minimum=14, maximum=119)
# Out:
# DataFrame 1:
# Number of rows with 0: 5462.
# Number of rows below 14: 5509.
# Number of rows above 119: 0.
#
# DataFrame 2:
# Number of rows with 0: 3248.
# Number of rows below 14: 3283.
# Number of rows above 119: 0.

# %% [markdown]
# 2. `Birth Year` with non-valid values
#
# Here, we take the previous limits into account to calculate limits to this variable. The values not within limits where replaced by missing values.

# %%
limit_feature([train_df, test_df], 'Birth Year', minimum=2024-119+1, maximum=2024-14+1)
# Out:
# DataFrame 1:
# Number of rows with 0: 25081.
# Number of rows below 1906: 25176.
# Number of rows above 2011: 7.
#
# DataFrame 2:
# Number of rows with 0: 19596.
# Number of rows below 1906: 19757.
# Number of rows above 2011: 10.

# %% [markdown]
# 3. A person's age shoud be greather than `Age at Injury`

# %%
# Calculate the age at accident (from the birth year and accident date)
train_df['Calculated_Age_at_Accident'] = train_df['Accident Date'].dt.year - train_df['Birth Year']

# Check for incoherencies when the values are not missing
train_df[(train_df['Age at Injury'].notna()) & 
                 (train_df['Calculated_Age_at_Accident'].notna()) &
                 (train_df['Age at Injury'] != train_df['Calculated_Age_at_Accident']) &
                 (abs(train_df['Age at Injury'] - train_df['Calculated_Age_at_Accident']) > 1)]
# Out:
# Empty DataFrame
# Columns: [Accident Date, Age at Injury, Alternative Dispute Resolution, Assembly Date, Attorney/Representative, Average Weekly Wage, Birth Year, C-2 Date, C-3 Date, Carrier Name, Carrier Type, Claim Injury Type, County of Injury, COVID-19 Indicator, District Name, First Hearing Date, Gender, IME-4 Count, Industry Code, Industry Code Description, Medical Fee Region, OIICS Nature of Injury Description, WCIO Cause of Injury Code, WCIO Cause of Injury Description, WCIO Nature of Injury Code, WCIO Nature of Injury Description, WCIO Part Of Body Code, WCIO Part Of Body Description, Zip Code, Agreement Reached, WCB Decision, Number of Dependents, Calculated_Age_at_Accident]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# This never happens in our dataset.

# %%
# Drop created column
train_df = train_df.drop('Calculated_Age_at_Accident', axis=1)

# %% [markdown]
# 4. `Average Weekly Wage` should not be equal to 0

# %%
limit_feature([train_df, test_df], 'Average Weekly Wage', minimum=1, maximum=None)
# Out:
# DataFrame 1:
# Number of rows with 0: 335448.
# Number of rows below 1: 335448.
#
# DataFrame 2:
# Number of rows with 0: 316549.
# Number of rows below 1: 316549.

# %% [markdown]
# 5. Compare the variables `Industry Code` and `Industry Code Description`

# %%
# Count the number of unique descriptions for each Industry Code
industry_description_counts = train_df.groupby('Industry Code')['Industry Code Description'].nunique()

# Check if any Industry Code has more than 1 unique description
inconsistent_industry_codes = industry_description_counts[industry_description_counts > 1]

if len(inconsistent_industry_codes) > 0:
    print(f"These Industry Codes have inconsistent descriptions: {inconsistent_industry_codes}")
else:
    print("All Industry Codes have the same description across the dataset.")
# Out:
# All Industry Codes have the same description across the dataset.

# %% [markdown]
# 6. Presence of UNKNO in  `WCIO Cause of Injury Code`, `WCIO Nature of Injury Code`, `WCIO Part Of Body Code` and  `Zip Code `

# %%
columns_with_UNKNO = [
    'WCIO Cause of Injury Code',
    'WCIO Nature of Injury Code',
    'WCIO Part Of Body Code',
    'Zip Code'
]

for col in columns_with_UNKNO:
    train_df[col] = train_df[col].replace('UNKNO', 'Unknown')
    test_df[col] = test_df[col].replace('UNKNO', 'Unknown')

# %% [markdown]
# <a class="anchor" id="five-bullet">
#
# ## <span style="color:#568789"> 5. Handling Missing Values</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# Before starting, let's check the columns that can be dropped or inputed.

# %%
# Display the percentage of missing values per column

missing_values = train_df.isnull().sum() / len(train_df) * 100

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# OIICS Nature of Injury Description    100.000000
# IME-4 Count                            76.864556
# First Hearing Date                     73.730018
# C-3 Date                               67.380632
# Average Weekly Wage                    63.429229
# Birth Year                              9.452741
# WCIO Part Of Body Description           2.975485
# WCIO Nature of Injury Description       2.727238
# WCIO Cause of Injury Description        2.724276
# C-2 Date                                2.536131
# Age at Injury                           0.959716
# Accident Date                           0.642308
# dtype: float64

# %%
# Display the percentage of missing values per column

missing_values = test_df.isnull().sum() / len(test_df) * 100

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# OIICS Nature of Injury Description    100.000000
# IME-4 Count                            90.914621
# First Hearing Date                     88.909595
# Average Weekly Wage                    86.539854
# C-3 Date                               78.035698
# Birth Year                             10.113280
# WCIO Nature of Injury Description       2.721825
# WCIO Cause of Injury Description        2.667182
# WCIO Part Of Body Description           2.461241
# C-2 Date                                2.354275
# Age at Injury                           0.846189
# Accident Date                           0.629937
# dtype: float64

# %% [markdown]
# We decided to drop `OIICS Nature of Injury Description` because it only has missing values.

# %%
train_df = train_df.drop('OIICS Nature of Injury Description', axis = 1)
test_df = test_df.drop('OIICS Nature of Injury Description', axis = 1)

# %% [markdown]
# *Input `Accident Date`*

# %% [markdown]
# The second variable that we decided to tackle is `Accident Date`. While exploring the dataset, we noticed that in some cases that date is the same as `Assembly Date`. As such, we decided to replace the missing values with the other date.

# %%
train_df[train_df['Accident Date'] == train_df['Assembly Date']]
# Out:
#                  Accident Date  Age at Injury Alternative Dispute Resolution  \
# Claim Identifier
# 5393820             2020-01-02             57                              N
# 5394146             2020-01-02             76                              N
# 5394780             2020-01-02             65                              N
# 5394376             2020-01-02             37                              N
# 5395577             2020-01-03             58                              N
# ...                        ...            ...                            ...
# 6164198             2022-12-29             25                              N
# 6164657             2022-12-29             27                              N
# 6163731             2022-12-29             47                              N
# 6165526             2022-12-30             28                              N
# 6165254             2022-12-30             43                              N
#
#                  Assembly Date Attorney/Representative  Average Weekly Wage  \
# Claim Identifier
# 5393820             2020-01-02                       Y              2175.45
# 5394146             2020-01-02                       Y               549.26
# 5394780             2020-01-02                       N                  NaN
# 5394376             2020-01-02                       N              1124.57
# 5395577             2020-01-03                       N              1428.33
# ...                        ...                     ...                  ...
# 6164198             2022-12-29                       N                  NaN
# 6164657             2022-12-29                       N              1163.54
# 6163731             2022-12-29                       N                  NaN
# 6165526             2022-12-30                       N               900.00
# 6165254             2022-12-30                       N              1008.86
#
#                   Birth Year   C-2 Date   C-3 Date  \
# Claim Identifier
# 5393820                 1963 2020-06-05 2019-12-26
# 5394146                 <NA> 2020-02-11 2019-12-26
# 5394780                 1954 2020-01-02        NaT
# 5394376                 1982 2020-01-02        NaT
# 5395577                 1961 2020-01-03        NaT
# ...                      ...        ...        ...
# 6164198                 1997 2022-12-29        NaT
# 6164657                 1995 2022-12-29        NaT
# 6163731                 1975 2022-12-29        NaT
# 6165526                 1994 2022-12-30        NaT
# 6165254                 1979 2022-12-30        NaT
#
#                                 Carrier Name  ... WCIO Cause of Injury Code  \
# Claim Identifier                              ...
# 5393820            INDEMNITY INSURANCE CO OF  ...                      97.0
# 5394146               BOARD OF EDUCATION CNY  ...                      98.0
# 5394780                 STATE INSURANCE FUND  ...                      98.0
# 5394376              CHARTER OAK FIRE INS CO  ...                      18.0
# 5395577                 STATE INSURANCE FUND  ...                      17.0
# ...                                      ...  ...                       ...
# 6164198                 STATE INSURANCE FUND  ...                      97.0
# 6164657                 STATE INSURANCE FUND  ...                      32.0
# 6163731           WEGMANS FOOD MARKETS, INC.  ...                      32.0
# 6165526                 STATE INSURANCE FUND  ...                      54.0
# 6165254                 STATE INSURANCE FUND  ...                      18.0
#
#                  WCIO Cause of Injury Description WCIO Nature of Injury Code  \
# Claim Identifier
# 5393820                         REPETITIVE MOTION                       78.0
# 5394146                           CUMULATIVE, NOC                       59.0
# 5394780                           CUMULATIVE, NOC                       52.0
# 5394376              POWERED HAND TOOL, APPLIANCE                       40.0
# 5395577            OBJECT BEING LIFTED OR HANDLED                       40.0
# ...                                           ...                        ...
# 6164198                         REPETITIVE MOTION                       52.0
# 6164657                            ON ICE OR SNOW                       10.0
# 6163731                            ON ICE OR SNOW                       52.0
# 6165526                        JUMPING OR LEAPING                       46.0
# 6165254              POWERED HAND TOOL, APPLIANCE                       40.0
#
#                  WCIO Nature of Injury Description WCIO Part Of Body Code  \
# Claim Identifier
# 5393820                     CARPAL TUNNEL SYNDROME                   39.0
# 5394146           ALL OTHER SPECIFIC INJURIES, NOC                   31.0
# 5394780                             STRAIN OR TEAR                   38.0
# 5394376                                 LACERATION                   36.0
# 5395577                                 LACERATION                   19.0
# ...                                            ...                    ...
# 6164198                             STRAIN OR TEAR                   42.0
# 6164657                                  CONTUSION                   42.0
# 6163731                             STRAIN OR TEAR                   42.0
# 6165526                                    RUPTURE                   55.0
# 6165254                                 LACERATION                   34.0
#
#                  WCIO Part Of Body Description Zip Code  Agreement Reached  \
# Claim Identifier
# 5393820                    WRIST (S) & HAND(S)    13476                0.0
# 5394146                              UPPER ARM    75056                0.0
# 5394780                            SHOULDER(S)    14042                0.0
# 5394376                              FINGER(S)    11714                0.0
# 5395577                           FACIAL BONES    11901                0.0
# ...                                        ...      ...                ...
# 6164198                        LOWER BACK AREA    11726                0.0
# 6164657                        LOWER BACK AREA    11356                0.0
# 6163731                        LOWER BACK AREA    14215                0.0
# 6165526                                  ANKLE  10031.0                0.0
# 6165254                                  WRIST  12550.0                0.0
#
#                       WCB Decision Number of Dependents
# Claim Identifier
# 5393820           Not Work Related                  1.0
# 5394146           Not Work Related                  2.0
# 5394780           Not Work Related                  5.0
# 5394376           Not Work Related                  1.0
# 5395577           Not Work Related                  1.0
# ...                            ...                  ...
# 6164198           Not Work Related                  3.0
# 6164657           Not Work Related                  6.0
# 6163731           Not Work Related                  6.0
# 6165526           Not Work Related                  0.0
# 6165254           Not Work Related                  1.0
#
# [3550 rows x 31 columns]

# %%
# Filter the rows where 'Accident Date' is NaN, but 'Assembly Date' is not NaN
condition = train_df['Accident Date'].isna() & train_df['Assembly Date'].notna()

# Replace missing 'Accident Date' with 'Assembly Date' where the condition is true
train_df.loc[condition, 'Accident Date'] = train_df.loc[condition, 'Assembly Date']

# %%
# Filter the rows where 'Accident Date' is NaN, but 'Assembly Date' is not NaN in the test dataset
condition = test_df['Accident Date'].isna() & test_df['Assembly Date'].notna()

# Replace missing 'Accident Date' with 'Assembly Date' where the condition is true in the test dataset
test_df.loc[condition, 'Accident Date'] = test_df.loc[condition, 'Assembly Date']

# %% [markdown]
# *Calculate `Age at Injury`*

# %% [markdown]
# Afte, we can easily input are related to age/birth year. By using the relationship between `Age at Injury`, `Accident Date` and `Birth Year`, we can easily calculate some missing values.

# %%
# Filter the rows where 'Age at Injury' is NaN, but 'Birth Year' and 'Accident Date' are not NaN
condition = train_df['Age at Injury'].isna() & train_df['Birth Year'].notna() & train_df['Accident Date'].notna()

# Replace missing 'Age at Injury' with the difference between 'Accident Date' and 'Birth Year'
train_df.loc[condition, 'Age at Injury'] = train_df.loc[condition, 'Accident Date'].dt.year - train_df.loc[condition, 'Birth Year']


# Filter the rows where 'Age at Injury' is NaN, but 'Birth Year' and 'Accident Date' are not NaN in the test dataset
condition = test_df['Age at Injury'].isna() & test_df['Birth Year'].notna() & test_df['Accident Date'].notna()

# Replace missing 'Age at Injury' with the difference between 'Accident Date' and 'Birth Year' where the condition is true
test_df.loc[condition, 'Age at Injury'] = test_df.loc[condition, 'Accident Date'].dt.year - test_df.loc[condition, 'Birth Year']

# %% [markdown]
# *Calculate `Birth Year`*

# %%
# Filter the rows where 'Birth Year' is NaN, but 'Age at Injury' and 'Accident Date' are not NaN
condition = train_df['Birth Year'].isna() & train_df['Age at Injury'].notna() & train_df['Accident Date'].notna()

# Replace missing 'Birth Year' with the difference between 'Accident Date' year and 'Age at Injury'
train_df.loc[condition, 'Birth Year'] = train_df.loc[condition, 'Accident Date'].dt.year - train_df.loc[condition, 'Age at Injury']


# Filter the rows where 'Birth Year' is NaN, but 'Age at Injury' and 'Accident Date' are not NaN in the test dataset
condition = test_df['Birth Year'].isna() & test_df['Age at Injury'].notna() & test_df['Accident Date'].notna()

# Replace missing 'Birth Year' with the difference between 'Accident Date' year and 'Age at Injury' where the condition is true
test_df.loc[condition, 'Birth Year'] = test_df.loc[condition, 'Accident Date'].dt.year - test_df.loc[condition, 'Age at Injury']

# %% [markdown]
# *Input `IME-4 Count`*

# %% [markdown]
# The next colum is `IME-4 Count` which also has a high number of missing values. In this case, we started to explore the values that the variable already had.

# %%
train_df['IME-4 Count'].unique()
# Out:
# array([nan,  4.,  1.,  3.,  2.,  6.,  7.,  5., 10., 12.,  8.,  9., 11.,
#        13., 14., 36., 15., 20., 19., 18., 27., 17., 16., 24., 22., 26.,
#        21., 23., 30., 32., 39., 25., 29., 47., 48., 34., 28., 37., 31.,
#        35., 33., 73.])

# %% [markdown]
# As this variables represents the number of IME-4 forms received per claim and its never 0, we reached the conclusion that the missing values represent that no IME-4 form was received. As such, we decided to replace the missing values with 0.

# %%
train_df['IME-4 Count'] = train_df['IME-4 Count'].fillna(0)
test_df['IME-4 Count'] = test_df['IME-4 Count'].fillna(0)

# %% [markdown]
# *Some Conclusions*

# %% [markdown]
# As for the other columns like `WCIO Part Of Body Description`, `WCIO Nature of Injury Description` and `WCIO Cause of Injury Description`, they are only essential to interpret the codes in the other columns so we decided not to do anything.

# %% [markdown]
# To conclude this section, we decided to see how many missing values we still have.

# %%
# Display the percentage of missing values per column

missing_values = train_df.isnull().sum() / len(train_df) * 100

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# First Hearing Date                   73.730018
# C-3 Date                             67.380632
# Average Weekly Wage                  63.429229
# WCIO Part Of Body Description         2.975485
# WCIO Nature of Injury Description     2.727238
# WCIO Cause of Injury Description      2.724276
# C-2 Date                              2.536131
# Age at Injury                         0.401377
# Birth Year                            0.401377
# dtype: float64

# %%
# Display the percentage of missing values per column

missing_values = test_df.isnull().sum() / len(test_df) * 100

missing_values[missing_values > 0].sort_values(ascending=False)
# Out:
# First Hearing Date                   88.909595
# Average Weekly Wage                  86.539854
# C-3 Date                             78.035698
# WCIO Nature of Injury Description     2.721825
# WCIO Cause of Injury Description      2.667182
# WCIO Part Of Body Description         2.461241
# C-2 Date                              2.354275
# Age at Injury                         0.300277
# Birth Year                            0.300277
# dtype: float64

# %% [markdown]
# The variables `Age at Injury`, `Birth Year` and `Average Weekly Wage` will be imputed using the median. However, due to the high amount of missing values in the last one, there is a high chance that it will not be used. As for the other two, only one will be imputed because the other can be calculated after having the other one. It is worth to mention that this imputation can only happen after we split our data to avoid data leakage.

# %% [markdown]
# In the variable `First Hearing Date`, a blank space means the the claim has not yet had a hearing held. Additionally, missing values in `C2-Date` and `C3-Date` mean that the event is yet to happen. To distinguish this NAs from true missing values, we decided to replace them with -1. THis will be done in the section of feature engineering.

# %% [markdown]
# <a class="anchor" id="six-bullet">
#
# ## <span style="color:#568789"> 6. Removing Outliers & Changing Distributions</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# After checking the distribution of our features in the previous notebooks, it is time to remove the outliers. This can only be done after we split the data so we used a copy of the dataframe to see our end results if our training dataset was only used for training. The transformations that we did can already be applied because there is no risk of data leakage.

# %%
copy_df = train_df.copy()

# %% [markdown]
# 1. The feature `Age at Injuty` already had some rows removed due to incoherencies. Due to the right-skewed distribution and the variables itself, we decided to additionally remove people with more than 90 years.

# %%
copy_df = copy_df[copy_df['Age at Injury'].le(90) | copy_df['Age at Injury'].isna()]

# %%
# Plot used to change the threshold, final distribution is below
plot_distribution_and_boxplot(copy_df, 'Age at Injury')

# %% [markdown]
# 2. The distribution of `Average Weekly Wage` could not be seen mainly due to the 5 outliers that we could see in the boxplot. As such, we decided to remove them.

# %%
copy_df = copy_df[copy_df['Average Weekly Wage'].lt(100000) | copy_df['Average Weekly Wage'].isna()]

# %% [markdown]
# After, that, we checked the distribution without those outliers. It was right-skewed, so we decided to apply a log transformation to reduce the skewness.

# %%
train_df['Average Weekly Wage'] = train_df['Average Weekly Wage'].apply(lambda x: np.log10(x) if x > 0 else np.nan)
copy_df['Average Weekly Wage'] = copy_df['Average Weekly Wage'].apply(lambda x: np.log10(x) if x > 0 else np.nan)

# %%
# Plot used to change the threshold, final distribution is below
# plot_distribution_and_boxplot(train_df, 'Average Weekly Wage')

# %% [markdown]
# As this transformation resulted in a reduced skewness and this is going to be the data that we are going to use, we also have to apply this transformation in the test dataset.

# %%
test_df['Average Weekly Wage'] = test_df['Average Weekly Wage'].apply(lambda x: np.log10(x) if x > 0 else np.nan)

# %% [markdown]
# 3. The next variable is `Birth Year`. The distribution is already normal but some outliers can be seen in the boxplot. As such, we decided to remove them.

# %%
copy_df = copy_df[copy_df['Birth Year'].gt(1938) | copy_df['Birth Year'].isna()]

# %%
# Plot used to change the threshold, final distribution is below
# plot_distribution_and_boxplot(train_df, 'Birth Year')

# %% [markdown]
# 4. The next feature is `IME-4 Count`. It's distribution is extremely right skewed and we can detected some outliers in the boxplot of the variable. As such, we decided to start by removing the outliers.

# %%
copy_df = copy_df[copy_df['IME-4 Count'].lt(40)] # Has no missing values

# %% [markdown]
# Our next step was to reduce the skewness of the variable. As it has the value of 0, we can not apply a log distribution. As such, we decided to use the square root which has to be applied in both datasets.

# %%
train_df['IME-4 Count'] = train_df['IME-4 Count'].apply(lambda x: np.sqrt(x) if x > 0 else 0)
copy_df['IME-4 Count'] = copy_df['IME-4 Count'].apply(lambda x: np.sqrt(x) if x > 0 else 0)

# %%
test_df['IME-4 Count'] = test_df['IME-4 Count'].apply(lambda x: np.sqrt(x) if x > 0 else 0)

# %%
# Plot used to change the threshold, final distribution is below
# plot_distribution_and_boxplot(train_df, 'IME-4 Count')

# %% [markdown]
# 5. As for the last numerical variable `Number of Dependents`, there were no outliers and it was uniformly distributed.

# %%
print(f'Our training dataset was reduced by {((initial_row_count - copy_df.shape[0])/ initial_row_count)*100}%.')
# Out:
# Our training dataset was reduced by 0.11881036332975624%.

# %% [markdown]
# <a class="anchor" id="seven-bullet">
#
# ## <span style="color:#568789"> 7. Feature Engineering</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# #### <span style="color:#568789"> 7.1 Creating New Features </span>

# %% [markdown]
# *Date Features*
#
# Dates can hold a lot of valuable information. We can extract components like year, month, and day of the week, which may capture seasonality or trends.<br><br>
# For the date columns:<br>
# __1. Year, Month, Day:__ These could provide insights on seasonality.<br>
# __2. Day of Week:__ Useful for identifying patterns on specific days.<br>
# __3. Time Differences:__ Calculating time spans between dates can be useful for tracking progress or delays in cases.
#
# Due to the high amount of missing values in these columns (sometimes because the event did not happen yet), we decided to create some variables that inform us if the date exists or not.

# %%
date_columns = ['Accident Date', 'Assembly Date', 'C-2 Date', 'C-3 Date', 'First Hearing Date', 'Age at Injury', 'Birth Year']

for col in date_columns:
    train_df[f"Known {col}"] = train_df[col].notna().astype(int)
    test_df[f"Known {col}"] = test_df[col].notna().astype(int)

# %%
# Create columns for year, month, day, and day of the week
date_columns = ['Accident Date', 'Assembly Date', 'C-2 Date', 'C-3 Date', 'First Hearing Date']
extract_dates_components([train_df, test_df], date_columns)

# %% [markdown]
# *Calculate Time Differences*
#
# Create new columns to capture the elapsed time between key dates, which can help understand delays or the timeline of events.

# %%
dist_dates([train_df, test_df])

# %% [markdown]
# *Seasonality of Accident Date*
#
# Create column that indicates the season in which the accident happened.

# %%
# Apply the function to the 'Accident Date' column
train_df['Accident_Season'] = train_df['Accident Date'].apply(get_season)
test_df['Accident_Season'] = test_df['Accident Date'].apply(get_season)

# %% [markdown]
# *Accident Timing Indicator (Weekend or Holiday)*
#
# Create columns that indicate if the accident happened on a weekend or a holiday.

# %%
# Flag public holidays
train_df = flag_public_holiday_accidents(train_df, 'Accident Date')
test_df = flag_public_holiday_accidents(test_df, 'Accident Date')

# %%
# Flag weekends
train_df = flag_weekend_accidents(train_df, 'Accident Date')
test_df = flag_weekend_accidents(test_df, 'Accident Date')

# %% [markdown]
# *Risk Level*
#
# Create a column that indicates how dangerous the industry of the worker is.

# %%
Risk_map = {
    "HEALTH CARE AND SOCIAL ASSISTANCE": 1,  # Medium risk
    "PUBLIC ADMINISTRATION": 0,             # Low risk
    "RETAIL TRADE": 1,                      # Medium risk
    "TRANSPORTATION AND WAREHOUSING": 2,    # High risk
    "EDUCATIONAL SERVICES": 0,              # Low risk
    "MANUFACTURING": 2,                     # High risk
    "CONSTRUCTION": 2,                      # High risk
    "ACCOMMODATION AND FOOD SERVICES": 1,   # Medium risk
    "ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMENT AND REMEDIAT": 1, # Medium risk
    "WHOLESALE TRADE": 1,                   # Medium risk
    "OTHER SERVICES (EXCEPT PUBLIC ADMINISTRATION)": 0, # Low risk
    "ARTS, ENTERTAINMENT, AND RECREATION": 1,           # Medium risk
    "PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES": 0, # Low risk
    "INFORMATION": 0,                        # Low risk
    "REAL ESTATE AND RENTAL AND LEASING": 0, # Low risk
    "FINANCE AND INSURANCE": 0,              # Low risk
    "UTILITIES": 2,                          # High risk
    "AGRICULTURE, FORESTRY, FISHING AND HUNTING": 2, # High risk
    "MINING": 2,                             # High risk
    "MANAGEMENT OF COMPANIES AND ENTERPRISES": 0, # Low risk
    "nan": 1 # Medium Risk
}

# %%
train_df["Risk_Level"] = train_df["Industry Code Description"].map(Risk_map)
test_df["Risk_Level"] = test_df["Industry Code Description"].map(Risk_map)

# %% [markdown]
# #### <span style="color:#568789"> 7.2 Transforming Existing Features </span>

# %% [markdown]
# *Modifying `Carrier Type`*
#
# In the `Carrier Type` column, there are three values that are similar which represent different types of special funds. Only 9 special funds could be identified, leaving 1023 unkown. As such, we decided to join all of them in the unkown special funds.

# %%
train_df['Carrier Type'] = train_df['Carrier Type'].replace({'5C. SPECIAL FUND - POI CARRIER WCB MENANDS': '5D. SPECIAL FUND - UNKNOWN'})
train_df['Carrier Type'] = train_df['Carrier Type'].replace({'5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)': '5D. SPECIAL FUND - UNKNOWN'})

test_df['Carrier Type'] = test_df['Carrier Type'].replace({'5C. SPECIAL FUND - POI CARRIER WCB MENANDS': '5D. SPECIAL FUND - UNKNOWN'})
test_df['Carrier Type'] = test_df['Carrier Type'].replace({'5A. SPECIAL FUND - CONS. COMM. (SECT. 25-A)': '5D. SPECIAL FUND - UNKNOWN'})

# %% [markdown]
# *Modifying `Gender`*
#
# In the `Gender` column, we replaced the values `U` and `X` with `Unknown`. The value `U` typically indicates "unknown" or unspecified gender, while `X` may signify a non-binary identity. By combining these two values into `Unknown`, we simplify the data, making it easier to analyze and interpret.

# %%
# Replace 'U' with 'Unknown'
train_df['Gender'] = train_df['Gender'].replace({'U': 'Unknown'})
# Replace 'X' with 'Unknown'
train_df['Gender'] = train_df['Gender'].replace({'X': 'Unknown'})

# Replace 'U' with 'Unknown'
test_df['Gender'] = test_df['Gender'].replace({'U': 'Unknown'})
# Replace 'X' with 'Unknown'
test_df['Gender'] = test_df['Gender'].replace({'X': 'Unknown'})

# %% [markdown]
# | New Feature  | how were created | description | why they were created |
# |--------------|------------------|-------------|-----------------------|
# | Kown_{Accident Date' + 'Assembly Date' + 'C-2 Date' + 'C-3 Date' + 'First Hearing Date' + 'Age at Injury' + 'Birth Year'} | Extracting data components | Create columns for year, month, day, and day of the week   | Due to the high amount of missing values in these columns (sometimes because the event did not happen yet), we decided to create some variables that inform us if the date exists or not |
# | Kown_{'Days_to_First_Hearing' + 'Days_to_C2' + 'Days_to_C3'} | Calculate the time difference between relevant dates | new columns to capture the elapsed time between key dates | can help understand delays or the timeline of events|
# | 'Accident_Season' | assigns a season based on the exact date  | column that indicates the season in which the accident happened. | In order to know in which season the accident happen  |
# | 'Weekend_Accident' |  Add holidays for the current year to the list | Create columns that indicate if the accident happened on a weekend or a holiday   | To know if the accidents happend on a weekend or a holiday |
# | 'Risk_Level' | create a dictionary with the correspondent risk  | Create a column that indicates how dangerous the industry of the worker is   | To see how danger is working in each industry  |
# | 'Relative_Wage' | Calculate whether the injured worker’s wage is above or below the median wage for the dataset | Relative Wage Compared to Median Wage  | it's potentially reflecting job type or socioeconomic factors |
# | 'Financial Impact Category' | calculated as the Average Weekly Wage divided by the adjusted number of dependents |  inancial impact per dependent based on the weekly wage  |  categorizes this financial burden into predefined groups for easier analysis  |
# | 'Age_Group' | converts the categorized values into numeric codes  |  Group ages into categories like "young" or "senior"  |  capture different risk profiles  |

# %% [markdown]
# | Trasform Existing Feature  | how were created | description | why they were created |
# |----------------------------|------------------|-------------|-----------------------|
# | 'Carrier Type' | join all of the special funds in the unkown special funds | Type of primary insurance provider responsible for providing workers’ compensation coverage  |  there are three values that are similar which represent different types of special funds |
# | 'Gender' | Replace 'U' for 'Unknown' and 'X' for 'Unknown' | The reported gender of the injured worker |  making it easier to analyze and interpret |

# %% [markdown]
# <a class="anchor" id="eight-bullet">
#
# ## <span style="color:#568789"> 8. Visualizations</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# After all the modifications that we did, let's check how our variables changed.

# %% [markdown]
# Let's start with the distribution of the numerical features.

# %%
numerical_features = [
    'Age at Injury', 'Average Weekly Wage', 'Birth Year', 'IME-4 Count', 'Number of Dependents'
]
numerical_df = copy_df[numerical_features]

# %%
fig, axes = plt.subplots(len(numerical_features), 2, figsize=(15, 5*len(numerical_features)))
fig.suptitle('Distribution of Numerical Features', fontsize=16, y=1.02)

for idx, feature in enumerate(numerical_features):
    # Histogram with KDE
    sns.histplot(data=numerical_df, x=feature, kde=True, ax=axes[idx, 0], color=plot_color)
    axes[idx, 0].set_title(f'Distribution of {feature}')
    axes[idx, 0].set_xlabel(feature)
        
    # Box plot - Use the color parameter instead of palette
    sns.boxplot(data=numerical_df, y=feature, ax=axes[idx, 1], color=plot_color)
    axes[idx, 1].set_title(f'Box Plot of {feature}')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Distribution Analysis of Numerical Features
#
# ## Age at Injury
# * The distribution shows a bimodal pattern, with peaks around age 35 and 55
# * Ages range primarily from 20 to 70 years old
# * The box plot indicates:
#  - Median age around 40 years
#  - Interquartile range approximately between 30 and 55 years
#  - Some outliers above age 70 and below age 20
#
# ## Average Weekly Wage
# * Highly right-skewed distribution with majority of wages clustered at lower values
# * Box plot reveals:
#  - Numerous high-value outliers
#  - Most wages concentrated in lower range
#  - Several extreme outliers above $60,000 weekly
# * Most common wages appear to be under $20,000 weekly
#
# ## Birth Year
# * Similar pattern to Age at Injury (inversely)
# * Distribution spans from approximately 1940 to 2010
# * Bimodal distribution with peaks around:
#  - Early 1960s
#  - Mid-1980s
# * Box plot shows:
#  - Median birth year around 1975
#  - Most birth years fall between 1960 and 1990
#
# ## IME-4 Count
# * Extremely right-skewed distribution
# * Vast majority of cases have 0 or 1 IME-4 counts
# * Box plot shows:
#  - Multiple outliers above 2 counts
#  - Maximum values reaching 6
#  - Most cases concentrated at lower values
#
# ## Number of Dependents
# * Discrete distribution with clear peaks at whole numbers
# * Ranges from 0 to 6 dependents
# * Most frequent values are 0 and 1 dependents
# * Box plot indicates:
#  - Median around 2-3 dependents
#  - Full range from 0 to 6
#  - Relatively even distribution across values
#
# ## Overall Patterns
# * Most features show non-normal distributions
# * Several features (Average Weekly Wage, IME-4 Count) have significant outliers
# * Age and Birth Year show related bimodal patterns, suggesting two distinct age groups in the population
# * Strong discretization in Number of Dependents data

# %%
categorical_features = [
    'Alternative Dispute Resolution', 'Attorney/Representative',
    'Carrier Name',  'Carrier Type', 'County of Injury',
    'COVID-19 Indicator',  'District Name', 'Gender', 'Industry Code',
    'Industry Code Description',  'Medical Fee Region',  'WCIO Cause of Injury Code',
    'WCIO Cause of Injury Description',  'WCIO Nature of Injury Code',
    'WCIO Nature of Injury Description',  'WCIO Part Of Body Code',
    'WCIO Part Of Body Description',  'Zip Code', 'Agreement Reached',
    'WCB Decision', 'Claim Injury Type'
]

categorical_df = train_df[categorical_features]
categorical_df
# Out:
#                  Alternative Dispute Resolution Attorney/Representative  \
# Claim Identifier
# 5393875                                       N                       N
# 5393091                                       N                       Y
# 5393889                                       N                       N
# 5393887                                       N                       N
# 5393863                                       N                       N
# ...                                         ...                     ...
# 6165265                                       N                       N
# 6165285                                       N                       N
# 6165506                                       N                       N
# 6165339                                       N                       N
# 6165075                                       N                       N
#
#                                     Carrier Name Carrier Type  \
# Claim Identifier
# 5393875               NEW HAMPSHIRE INSURANCE CO  1A. PRIVATE
# 5393091             ZURICH AMERICAN INSURANCE CO  1A. PRIVATE
# 5393889                INDEMNITY INSURANCE CO OF  1A. PRIVATE
# 5393887                     STATE INSURANCE FUND      2A. SIF
# 5393863              INDEMNITY INS. OF N AMERICA  1A. PRIVATE
# ...                                          ...          ...
# 6165265                     STATE INSURANCE FUND      2A. SIF
# 6165285                       WESCO INSURANCE CO  1A. PRIVATE
# 6165506           SECURITY NATIONAL INSURANCE CO  1A. PRIVATE
# 6165339            TECHNOLOGY INSURANCE CO. INC.  1A. PRIVATE
# 6165075            TECHNOLOGY INSURANCE CO. INC.  1A. PRIVATE
#
#                  County of Injury COVID-19 Indicator District Name Gender  \
# Claim Identifier
# 5393875              ST. LAWRENCE                  N      SYRACUSE      M
# 5393091                   WYOMING                  N     ROCHESTER      F
# 5393889                    ORANGE                  N        ALBANY      M
# 5393887                  DUTCHESS                  N        ALBANY      M
# 5393863                   SUFFOLK                  N     HAUPPAUGE      M
# ...                           ...                ...           ...    ...
# 6165265                     BRONX                  N           NYC      M
# 6165285                    NASSAU                  N           NYC      M
# 6165506                      ERIE                  N       BUFFALO      F
# 6165339                  NEW YORK                  N           NYC      F
# 6165075                  SULLIVAN                  N    BINGHAMTON      F
#
#                  Industry Code  \
# Claim Identifier
# 5393875                   44.0
# 5393091                   23.0
# 5393889                   56.0
# 5393887                   62.0
# 5393863                   44.0
# ...                        ...
# 6165265                   56.0
# 6165285                   62.0
# 6165506                   62.0
# 6165339                   62.0
# 6165075                   48.0
#
#                                           Industry Code Description  ...  \
# Claim Identifier                                                     ...
# 5393875                                                RETAIL TRADE  ...
# 5393091                                                CONSTRUCTION  ...
# 5393889           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...  ...
# 5393887                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 5393863                                                RETAIL TRADE  ...
# ...                                                             ...  ...
# 6165265           ADMINISTRATIVE AND SUPPORT AND WASTE MANAGEMEN...  ...
# 6165285                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165506                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165339                           HEALTH CARE AND SOCIAL ASSISTANCE  ...
# 6165075                              TRANSPORTATION AND WAREHOUSING  ...
#
#                  WCIO Cause of Injury Code  \
# Claim Identifier
# 5393875                               27.0
# 5393091                               97.0
# 5393889                               79.0
# 5393887                               16.0
# 5393863                               31.0
# ...                                    ...
# 6165265                               45.0
# 6165285                               74.0
# 6165506                               98.0
# 6165339                               59.0
# 6165075                               25.0
#
#                              WCIO Cause of Injury Description  \
# Claim Identifier
# 5393875                          FROM LIQUID OR GREASE SPILLS
# 5393091                                     REPETITIVE MOTION
# 5393889                        OBJECT BEING LIFTED OR HANDLED
# 5393887                       HAND TOOL, UTENSIL; NOT POWERED
# 5393863                               FALL, SLIP OR TRIP, NOC
# ...                                                       ...
# 6165265           COLLISION OR SIDESWIPE WITH ANOTHER VEHICLE
# 6165285                FELLOW WORKER, PATIENT OR OTHER PERSON
# 6165506                                       CUMULATIVE, NOC
# 6165339                               USING TOOL OR MACHINERY
# 6165075                      FROM DIFFERENT LEVEL (ELEVATION)
#
#                  WCIO Nature of Injury Code WCIO Nature of Injury Description  \
# Claim Identifier
# 5393875                                10.0                         CONTUSION
# 5393091                                49.0                    SPRAIN OR TEAR
# 5393889                                 7.0                        CONCUSSION
# 5393887                                43.0                          PUNCTURE
# 5393863                                10.0                         CONTUSION
# ...                                     ...                               ...
# 6165265                                10.0                         CONTUSION
# 6165285                                37.0                      INFLAMMATION
# 6165506                                80.0  ALL OTHER CUMULATIVE INJURY, NOC
# 6165339                                59.0  ALL OTHER SPECIFIC INJURIES, NOC
# 6165075                                90.0   MULTIPLE PHYSICAL INJURIES ONLY
#
#                  WCIO Part Of Body Code WCIO Part Of Body Description  \
# Claim Identifier
# 5393875                            62.0                      BUTTOCKS
# 5393091                            38.0                   SHOULDER(S)
# 5393889                            10.0          MULTIPLE HEAD INJURY
# 5393887                            36.0                     FINGER(S)
# 5393863                            38.0                   SHOULDER(S)
# ...                                 ...                           ...
# 6165265                            42.0               LOWER BACK AREA
# 6165285                            35.0                          HAND
# 6165506                            34.0                         WRIST
# 6165339                            55.0                         ANKLE
# 6165075                            -9.0                      MULTIPLE
#
#                  Zip Code Agreement Reached      WCB Decision  \
# Claim Identifier
# 5393875             13662               0.0  Not Work Related
# 5393091             14569               1.0  Not Work Related
# 5393889             12589               0.0  Not Work Related
# 5393887             12603               0.0  Not Work Related
# 5393863             11772               0.0  Not Work Related
# ...                   ...               ...               ...
# 6165265           10467.0               0.0  Not Work Related
# 6165285           11590.0               0.0  Not Work Related
# 6165506           14227.0               0.0  Not Work Related
# 6165339           10029.0               0.0  Not Work Related
# 6165075           12779.0               0.0  Not Work Related
#
#                  Claim Injury Type
# Claim Identifier
# 5393875                2. NON-COMP
# 5393091               4. TEMPORARY
# 5393889               4. TEMPORARY
# 5393887                2. NON-COMP
# 5393863                3. MED ONLY
# ...                            ...
# 6165265                2. NON-COMP
# 6165285                2. NON-COMP
# 6165506               4. TEMPORARY
# 6165339                2. NON-COMP
# 6165075                2. NON-COMP
#
# [574024 rows x 21 columns]

# %%
# Plot the heatmap with the custom gradient colormap
plt.figure(figsize=(10, 8))
correlation_matrix = numerical_df.corr()

sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap=custom_cmap,  # Apply the custom gradient colormap
            center=0,
            fmt='.2f',
            cbar_kws={"shrink": .8})  # Adjust color bar size if needed

plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %%
plot_categorical_features(categorical_df)
# Out:
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')
# e:\Master Projects\MLFlow-in-Claim-Injury-Prediction\utils\utils.py:193: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[i].set_xticklabels(axes[i].get_xticklabels(), rotation=45, ha='right')

# %% [markdown]
# When comparing these graphs with the ones in the EDA, there are no big differences important to note. The main information maintains the same as before these changes.

# %% [markdown]
# ### <span style="color:#568789"> 8.1 Multivariate exploration </span>

# %% [markdown]
# About the numerical features, we can see in this plot the multivariate exploration in order to our target `Claim Injury Type`.

# %%
selected_features = ["Age at Injury", "Birth Year", "IME-4 Count", "Claim Injury Type"]
sns.pairplot(train_df[selected_features], hue="Claim Injury Type")
plt.show()

# %% [markdown]
# About this plot:
# - Distribution of Age at Injury:
#     - The age at injury spans a wide range, but there are significant concentrations in younger age groups (20-40 years).
#     - Injury types such as "TEMPORARY" (category 4) are more frequent in specific age ranges, suggesting that younger individuals might be more prone to temporary injuries.
# - Correlation with Birth Year:
#     - There is a strong negative relationship between birth year and age at injury (as expected, since more recent birth years correspond to younger ages).
# - IME-4 Count:
#     - The IME-4 count is predominantly low (between 0 and 2), but certain injury types, such as "TEMPORARY," are associated with higher counts.
#     - This suggests that certain injury types may require more IME-4 exams for evaluation.

# %% [markdown]
# About the categorical vars, we can do the same to see how work

# %%
selected_features_categoricas = [   
                                    "Carrier Type",
                                    "Gender",
                                    "District Name",
                                    "Claim Injury Type"
                                ]

# %%
# Copiando as colunas categóricas selecionadas para codificação
categorical_df_encoded = categorical_df[selected_features_categoricas].copy()

# Codificando variáveis categóricas
for col in selected_features_categoricas:
    categorical_df_encoded[col] = categorical_df_encoded[col].astype('category').cat.codes

# %%
sns.pairplot(categorical_df_encoded, hue="Claim Injury Type")
plt.show()

# %% [markdown]
# About this plot:
# - Carrier Type:
#     - Carrier types are primarily concentrated in lower values (0-2), indicating that most cases involve specific carrier categories.
# - Gender:
#     - There is a clear separation of gender (0 and 1), but the relationship between gender and injury types does not seem to vary significantly.
# - District Name:
#     - Certain districts (especially those with higher values) have a greater concentration of cases. This suggests that specific regions may have a higher incidence of claims or particular injury types.

# %% [markdown]
# <a class="anchor" id="nine-bullet">
#
# ## <span style="color:#568789"> 9. Variable Encoding</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# To use the categorical variables, it is necessary to encode them as most models do not accept non-numerical values. We used six different encoders:
#
# 1. **One-Hot Encoder**
#    Converts categories into binary columns (1/0). Best for low-cardinality features.
#
# 2. **Frequency Encoder**
#    Replaces categories with their occurrence counts. Good for high-cardinality features.
#
# 3. **Hash Encoder**
#    Maps categories into a fixed number of hash buckets. Useful for very high-cardinality features.
#
# 4. **Sine Cosine Encoder**
#    Represents cyclical features using sine and cosine transformations. For cyclical data like time or angles.
#
# 5. **Label Encoder**
#    Assigns a unique integer to each category. Suitable for ordinal features.
#
#
# ---
# #### **Variable Encoding Table**
#
# | **Variable Name**                     | **Encoding Method Used** |
# |---------------------------------------|--------------------------|
# | Accident Season                       | Sine Cosine Encoder      |
# | Alternative Dispute Resolution        | One-Hot Encoder          |
# | Attorney/Representative               | One-Hot Encoder          |
# | COVID-19 Indicator                    | One-Hot Encoder          |
# | County of Injury                      | Frequency Encoder        |
# | District Name                         | Frequency Encoder        |
# | Gender                                | One-Hot Encoder          |
# | Medical Fee Region                    | One-Hot Encoder          |
# | Zip Code                              | Frequency Encoder        |
# | Claim Injury Type                     | Label Encoder            |
# | Industry Code                         | Frequency Encoder        |
# | WCIO Cause of Injury Code             | Frequency Encoder        |
# | WCIO Nature of Injury Code            | Frequency Encoder        |
# | WCIO Part of Body Code                | Frequency Encoder        |
#
#
# However, not all encoders can be applied immediately. We can only apply the Frequency Encoder after splitting the data to avoid data leakage. Additionally, the Hash Encoder will only be applied after the Frequency Encoder if a feature has two or more values with the same frequency. For the other encoders this precaution is not necessary because they use the unique values of each row not their frequency.

# %% [markdown]
# *One-Hot Encoder*
#
# This encoder is manly applied to categorical features that are not ordinal and that do not have many unique values.

# %%
# Features for One Hot Encoding
one_hot_encoder_vars = [
    "Alternative Dispute Resolution",
    "Attorney/Representative",
    "Carrier Type",
    "COVID-19 Indicator",
    "Gender",
    "Medical Fee Region"
]

# Apply the function to the DataFrame
train_df, test_df = apply_one_hot_encoding(train_df, test_df, one_hot_encoder_vars, save_encoder=True)

# %% [markdown]
# *Frequency Encoder*
#
# This encoder will only be applied after we split our data.

# %%
# Variables for Frequency Encoder
frequency_encoder_vars = [
    "County of Injury",
    "District Name",
    "Zip Code",
    "Industry Code",
    "WCIO Cause of Injury Code",
    "WCIO Nature of Injury Code",
    "WCIO Part Of Body Code"
]

# %% [markdown]
# *Sine Cosine Encoder*
#
# The feature `Accident_Season` is a cyclic feature. As such, we decided to use this specific encoder.

# %%
season_mapping = {"Winter": 0, "Spring": 1, "Summer": 2, "Fall": 3}

# %%
train_df = sine_cosine_encoding(train_df, "Accident_Season", season_mapping )
test_df = sine_cosine_encoding(test_df, "Accident_Season", season_mapping)

# %% [markdown]
# *Label Encoder*
#
# This encoder will be applied in our target which only exists in the training dataset.

# %%
# Create a sorted list of unique categories in the 'Claim Injury Type' column of training_df
categories = sorted(cat for cat in train_df['Claim Injury Type'].unique())

# Initialize a LabelEncoder
label_encoder = LabelEncoder()

# Fit the LabelEncoder to the training data
label_encoder.fit(categories)

# Encode the 'Claim Injury Type' column in training_df
train_df['Claim Injury Type Encoded'] = label_encoder.transform(train_df['Claim Injury Type'])

# Save the fitted LabelEncoder to a file
joblib.dump(label_encoder, '../Encoders/LabelEncoder.pkl')
# Out:
# ['../Encoders/LabelEncoder.pkl']

# %%
# Save the encoder that is going to be applied to each variable
feat_enc = {'OneHotEncoder': one_hot_encoder_vars,
            'FrequencyEncoder': frequency_encoder_vars,
            'SineCosine': ['Accident_Season'],
            'LabelEncoder': ['Claim Injury Type']}

# Save the dictionary to a JSON file
with open('../Encoders/dic_4_encoding.json', 'w') as json_file:
    json.dump(feat_enc, json_file, indent=4)

# %% [markdown]
# <a class="anchor" id="ten-bullet">
#
# ## <span style="color:#568789"> 10. Export Datasets</span>
#
# <a href="#top">Top &#129033;</a>

# %% [markdown]
# Before exporting the datasets, we are going to remove the columns that we deemed unnecessary to train the models like features with descriptions and checking that we removed the features that we encoded. Additionally, we also remove the columns that do not appear in the test dataset from the training dataset.

# %%
code_descriptions = ["Industry Code Description",
                      "WCIO Cause of Injury Description",
                      "WCIO Nature of Injury Description",
                      "WCIO Part Of Body Description"]

# %%
train_df.drop(code_descriptions, axis=1, inplace=True)
test_df.drop(code_descriptions, axis=1, inplace=True)
train_df.drop(["Agreement Reached","WCB Decision"], axis=1, inplace = True) # Not in Test

# %%
to_drop = ["Attorney/Representative", "Carrier Type", "COVID-19 Indicator", "Gender", "Medical Fee Region",
           "Claim Injury Type", "Carrier Name",
           "First Hearing Date", "C-2 Date", "C-3 Date", "Assembly Date"
]

# %%
for col in to_drop:
    try:
        train_df.drop(col, axis=1, inplace=True)
    except KeyError:
        print(f"{col} not found in Train_df")
    try:
        test_df.drop(col, axis=1, inplace=True)
    except KeyError:
        print(f"{col} not found in Test_df")
# Out:
# Attorney/Representative not found in Train_df
# Attorney/Representative not found in Test_df
# Carrier Type not found in Train_df
# Carrier Type not found in Test_df
# COVID-19 Indicator not found in Train_df
# COVID-19 Indicator not found in Test_df
# Gender not found in Train_df
# Gender not found in Test_df
# Medical Fee Region not found in Train_df
# Medical Fee Region not found in Test_df
# Claim Injury Type not found in Test_df

# %% [markdown]
# Here, we finally export our data.

# %%
folder_path = "../data/preprocessed_data/"

if not os.path.exists(folder_path):
    os.makedirs(folder_path)
    print(f"Folder '{folder_path}' created.")
else:
    print(f"Folder '{folder_path}' already exists.")
# Out:
# Folder '../data/preprocessed_data/' created.

# %%
train_df.to_csv('../data/preprocessed_data/train_data.csv', index = True)
test_df.to_csv('../data/preprocessed_data/test_data.csv', index = True)
